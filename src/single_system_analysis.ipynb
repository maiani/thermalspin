# %% [markdown]
# #     Dynamic Analysis

# %%
#%matplotlib notebook

# %%
import numpy as np
import matplotlib.pyplot as plt
from thermalspin.data_analysis  import *

# %%
# Insert here the name of the simulation set
simname = "cover"

# %%
final_state, t, J, D, Hz, T, e, m = load_results(simname)

# %%
fig = plt.figure(figsize=(8,5))
ax = plt.subplot(111)
ax.plot(t,e)
plt.xlabel("Step")
plt.ylabel("Energy")
plt.grid()
plt.show()
plt.savefig("plots/hysteresis_energy.svg")

# %%
fig = plt.figure(figsize=(10,6))
ax = plt.subplot(111)
ax.plot(t, m[:,0], label = r"$M_x$")
ax.plot(t, m[:,1], label = r"$M_y$")
ax.plot(t, m[:,2], label = r"$M_z$")
plt.grid()
plt.legend()
plt.ylabel("Magnetization")
plt.xlabel("Steps")
plt.title("Magnetization")
plt.show()
plt.savefig("plots/hysteresis_magnetization.svg")

# %%
fig, ax = plot_state_2D(final_state, hls = True)
ax.view_init(elev=87, azim=0)
plt.axis('off')
fig.subplots_adjust(left=0, right=1, bottom=0, top=1)
fig.show()
fig.savefig('cover.png', bbox_inches='tight', pad_inches=0, dpi = 600)

# %%
fig, ax = plot_spin_directions(final_state, hls = True)
fig.show()
