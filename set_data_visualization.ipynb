# %% [markdown]
# #     RESULTS OF THE  SET OF SIMULATIONS

# %%
# %matplotlib notebook

# %%
import numpy as np
import matplotlib.pyplot as plt
from data_analysis  import *

# %%
final_state, t, J, h, T, e, m= load_set_results("test_16")

# %%
T_final = T[:, -1]

# %%
e_final = e[:, -1]

# %%
plt.figure()
plt.scatter(T_final, e_final)
plt.xlabel("Temperature")
plt.ylabel("Energy")
# Out:
# <img src="data:image/png;base64,..." width="640">
# Text(0,0.5,'Energy')

# %%
m_final = m[:,-1]

# %%
m_magnitude = np.sqrt(np.sum(m**2, axis = 2))
m_magnitude_final = np.sqrt(np.sum((m_final)**2, axis = 1))

# %%
plt.figure()
plt.scatter(T_final, m_magnitude_final)
plt.xlabel("Temperature")
plt.ylabel("Magnetization magnitude")
# Out:
# <img src="data:image/png;base64,..." width="640">
# Text(0,0.5,'Magnetization magnitude')

# %%
e_mean, e_rmsd, m_mean, m_rmsd = compute_set_statistics(e,m)

# %%
plt.figure()
plt.scatter(T_final, e_rmsd**2)
plt.xlabel("Temperature") 
plt.ylabel(r"$\langle \Delta E^2 \rangle$")
# Out:
# <img src="data:image/png;base64,..." width="640">
# Text(0,0.5,'$\\langle \\Delta E^2 \\rangle$')

# %%
plt.figure()
for i in range(0, t.shape[0]):
    plt.plot(t[i], m_magnitude[i])
plt.legend(T_final)
plt.xlabel("Step")
plt.ylabel("Absolute magnetization")
# Out:
# <img src="data:image/png;base64,..." width="640">
# Text(0,0.5,'Absolute magnetization')
